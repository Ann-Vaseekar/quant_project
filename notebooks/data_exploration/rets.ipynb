# %%
cd ../../
# Out:
# /Users/ann/Documents/Quant finance study/WSQ/project

# %%
from src.get_data.read_data import get_rets
# Out:
# 2026-02-10 18:46:58,987 INFO: Data loaded from src/misc/tickers.json

# %%
rets = get_rets(freq='4h',start_ts = '2023-01-01',end_ts='2025-12-31')
# Out:
#  54%|█████▍    | 775/1440 [05:07<04:23,  2.52it/s]
# /Users/ann/Documents/Quant finance study/WSQ/project/src/get_data/read_data.py:48: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   ret = px.pct_change().dropna(how="all",axis=0).dropna(how="all",axis=1)
# 2026-02-10 18:52:07,093 INFO: Data successfully written to src/misc/valid_tickers_2023_to_2025.json
